# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
tips = sns.load_dataset("tips")

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="day", y="total_bill", 
            hue="smoker", palette=["m","g"],
            data=tips)
sns.despine(offset=10, trim=True)

# %%
import seaborn as sns
sns.set_theme(style="ticks",palette="pastel")

# Load the example tips dataset
tips = sns.load_dataset("tips")

# %%
# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="day",y="total_bill",
            hue="smoker", palette=["m","g"],
            data=tips)
#sns.despine(offset=10, trim=True)

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
sns.boxplot(x=tips["total_bill"])

# %%
sns.boxplot(x="day", y="total_bill",
            data=tips)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.boxplot(x="day", y="total_bill",
            hue="smoker",
            data=tips)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="day", y="total_bill",
            hue="smoker", palette="Set3",
            data=tips)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="day",y="total_bill",
            hue="smoker", palette=["m","g"],
            data=tips)

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

diamonds = sns.load_dataset("diamonds")

f,ax = plt.subplots(figsize=(7,5))
sns.despine(f)

sns.histplot(
    diamonds,
    x="price",hue="cut",
    multiple="stack",
    palette="light:m_r",
    edgecolor=".3",
    linewidth=.5,
    log_scale=True,
)
ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
ax.set_xticks([500,1000,2000,5000,1000])
# Out:
# [<matplotlib.axis.XTick at 0x7fd79df3f9d0>,
#  <matplotlib.axis.XTick at 0x7fd79df3f610>,
#  <matplotlib.axis.XTick at 0x7fd79e723d10>,
#  <matplotlib.axis.XTick at 0x7fd79df14090>,
#  <matplotlib.axis.XTick at 0x7fd79d1823d0>]

# %%
diamonds = sns.load_dataset("diamonds")

# %%
diamonds.head(3)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31

# %%
diamonds["cut"].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
flights = sns.load_dataset("flights")
flights.head(3)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132

# %%
pivot_flights = flights.pivot("month","year","passengers")
pivot_flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
sns.heatmap(pivot_flights)

# %%
plt.figure(figsize=(15,10))
sns.heatmap(pivot_flights, annot=True, fmt="d")

# %%
plt.figure(figsize=(10,6))
sns.heatmap(pivot_flights, annot=True, fmt="d",cmap="YlGnBu")

# %%
import seaborn as sns
sns.set_theme(style="ticks")

df=sns.load_dataset("penguins")
sns.pairplot(df,hue="species")
